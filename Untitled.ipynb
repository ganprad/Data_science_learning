# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
loansData = pd.read_csv('https://spark-public.s3.amazonaws.com/dataanalysis/loansData.csv')

# %%
loansData['Interest.Rate'].head()
# Out:
# 81174     8.90%
# 99592    12.12%
# 80059    21.98%
# 15825     9.99%
# 33182    11.71%
# Name: Interest.Rate, dtype: object

# %%
#Making Interest.Rate into floats
loansData['Interest.Rate_pc_floats'] = loansData['Interest.Rate'].map(lambda x: float(x.split("%")[0]))

#Choosing midpoints of categorical variables that represent the FICO.Range
loansData['FICO.Score'] = loansData['FICO.Range'].map(lambda x : ((int(str(x).split("-")[0]) + int(str(x).split("-")[1]))/2.0))

#Removing "months" string from Loan.Length
loansData["Loan.Length_months"] = loansData["Loan.Length"].map(lambda x: int(x.split(" ")[0]))

#Removing % from debt to income ratio
loansData['Debt.To.Income.Ratio_pc'] = loansData['Debt.To.Income.Ratio'].map(lambda x: float(x.split("%")[0]))

# %%
#String splitting test
float("13.78%".split('%')[0])
# Out:
# 13.78

# %%
#String splitting test
((int("735-739".split("-")[0]) + int("735-739".split("-")[1]))/2.0)
# Out:
# 737.0

# %%
int("36 months".split(" ")[0])
# Out:
# 36

# %%
#loansData['Inquiries.in.the.Last.6.Months']

# %%
Vars = ['Amount.Requested','Amount.Funded.By.Investors','Interest.Rate_pc_floats',
               'Debt.To.Income.Ratio_pc',
                'FICO.Score']
Vars
# Out:
# ['Amount.Requested',
#  'Amount.Funded.By.Investors',
#  'Interest.Rate_pc_floats',
#  'Debt.To.Income.Ratio_pc',
#  'FICO.Score']

# %%
#pd.scatter_matrix(loansData, alpha=0.05,figsize=(10,10),diagonal='kde')
#plt.show()

# %%
#PairGrid class in Seaborn
g = sns.PairGrid(loansData,vars=Vars)
g = g.map_lower(sns.kdeplot)
g = g.map_diag(plt.hist)
g = g.map_upper(plt.scatter,s = 5)
g.savefig('scatterplot.pdf')
#g.map_diag(plt.hist)
#g.map_offdiag(plt.scatter)

# %%
intrate = loansData['Interest.Rate_pc_floats']
loanamt = loansData['Amount.Requested']
fico = loansData['FICO.Score']

# %%
y = np.matrix(intrate).transpose()
x1 = np.matrix(loanamt).transpose()
x2 = np.matrix(fico).transpose()
ones = np.ones(x1.shape)

# %%
#Linear regression using scikit-learn

#Setting up data for analysis
X = np.column_stack([x1,x2])

model = LinearRegression()
#Fitting model to data
model.fit(X,y)

#Testing model against data
model.score(X,y)

#Output predictions
predictions = model.predict(X)

SStot = np.sum((y-np.mean(y))*2)

SSres = np.sum((y-model.predict(X))*2)

Rsq = 1 - SStot/SSres
Rsq
# Out:
# 0.9478694469628286

# %%
#Linear regression using numpy.linalg routines 

X_np = np.column_stack([ones,x1,x2])

#Using numpy dot and inv operators

dot = np.dot
inv = np.linalg.inv

#Parameter column vector = ((X.T * X)^-1) * (X.T * y))

Betas = dot(inv(dot(X_np.T,X_np)),dot(X_np.T,y))
Betas
# Out:
# matrix([[  7.30596832e+01],
#         [  2.10747769e-04],
#         [ -8.84424222e-02]])

# %%
#Using numpy.linalg.lstsq

lstsq = np.linalg.lstsq

print lstsq(X_np,y)[0]
# Out:
# [[  7.30596832e+01]
#  [  2.10747769e-04]
#  [ -8.84424222e-02]]

# %%
model.predict(X)ww.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-afba68787ed8> in <module>()
# ----> 1 model.predict(X)
#
# /home/gpk/anaconda/lib/python2.7/site-packages/sklearn/linear_model/base.pyc in predict(self, X)
#     153             Returns predicted values.
#     154         """
# --> 155         return self.decision_function(X)
#     156
#     157     _center_data = staticmethod(center_data)
#
# /home/gpk/anaconda/lib/python2.7/site-packages/sklearn/linear_model/base.pyc in decision_function(self, X)
#     138         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     139         return safe_sparse_dot(X, self.coef_.T,
# --> 140                                dense_output=True) + self.intercept_
#     141
#     142     def predict(self, X):
#
# ...
